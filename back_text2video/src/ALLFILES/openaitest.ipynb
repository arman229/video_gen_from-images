# %%
def get_story_title_prompt(plot, language, child_age, child_name):
    prompt = (f"Write a title for a   story in {language} that is targeted towards a child in the age range {child_age}. "
              f"This story must include a character called {child_name}. The title of the story must be based on the following prompt:\n"
              f'"""\n{plot}\n"""')
    return prompt

 
def call_openai(userContents: str):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[ 
            {"role": "user", "content": userContents}
        ],
        max_tokens=1500  # Increase max_tokens if the story is long
    )
    return response.choices[0].message['content']

def get_story_text_prompt(plot, language, title, child_age, child_name, story_length):
    prompt = (f"Write a  story in {language} that fits the title {title} and is targeted towards a child in the age range {child_age}. "
              f"This story must include a character called {child_name}. The story should have a reading length of {story_length} min, "
              f"assuming the reader of the story is an adult. The plot of the story must be based on the following prompt:\n"
              f'"""\n{plot}\n"""')
    return prompt
def get_story_scenes_prompt(story_text):
    prompt = (f"You are given a bedtime story. Your task is to divide the story into scenes and return the scenes in JSON format. "
              f"Here is the full story:\n"
              f'"""\n{story_text}\n"""'
              f"Response should be strict JSON containing only the array of scenes descriptions in this format: [string,string,string,...].")
    return prompt
def get_scene_image_prompt(title, full_story, scene):
    prompt = (f"Consider a bedtime story that has the title: \"{title}\". The full story is:\n"
              f'"""\n{full_story}\n"""'
              f"Create an image that does not include text in the image and depicts the following scene, which has been taken from the full story:\n"
              f'"""\n{scene}\n"""'
              f"Avoid any content that may be considered inappropriate or offensive, ensuring the image aligns with content policies.")
    return prompt

plot = """
A 24 year old boy seeing out from a train’s window shouted…
“Dad, look the trees are going behind!”
Dad smiled and a young couple sitting nearby, looked at the 24 year old’s childish behavior with pity, suddenly he again exclaimed…
“Dad, look the clouds are running with us!”
The couple couldn’t resist and said to the old man…
“Why don’t you take your son to a good doctor?” The old man smiled and said…“I did and we are just coming from the hospital, my son was blind from birth, he just got his eyes today.”
Every single person on the planet has a story. Don’ t judge people be fore you truly know them. The truth might surprise you
"""
language = "English"
child_age = "5-7"
child_name = "Sam"
story_length = 1  # in minutes

 
story_generated_title = call_openai(get_story_title_prompt(plot, language, child_age, child_name))
story_generated =  call_openai(get_story_text_prompt(plot, language, story_generated_title, child_age, child_name, story_length))
print(story_generated)
scenes_of_story = call_openai(get_story_scenes_prompt(story_generated)) 
print(scenes_of_story)

# %%
import os
import openai
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

# %%
# text correction
import openai  
userContent="""in the past one crul roler whoese name is phoroh he belived he is a god  and god send a propht whose name is musa 
musa says you are not god but phoroah say i am god musa say god send a prophet musa for his message and give me mujza 
phoroh say you are magacian and than between musa and phoroh competaion at that time musa collect the magacins and game start  muagcians throgh snaks 
and than musa throug his ausa than asa becomes a long snaks and he feed the magcians snanks and than magacian says musa you are the true prophet of allah and than phoroh punish the 
magacians and not belive musa you are not a prophet still he say i am god  
"""
def chat(text: str)  :
    response  = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {
                "role": "system",
                "content": "You will be provided with statements, and your task is to convert them to standard English.",
            },
            {
                "role": "user",
                "content": text,
            }
        ],
        max_tokens=500,
    )
    return response.choices[0].message.content


print(chat(userContent))
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[6], line 27
#      10     response  = openai.ChatCompletion.create(
#      11         model="gpt-3.5-turbo",
#      12         messages=[
#    (...)     22         max_tokens=500,
#      23     )
#      24     return response.choices[0].message.content
# ---> 27 print(chat(userContent))
#
# Cell In[6], line 10, in chat(text)
#       9 def chat(text: str)  :
# ---> 10     response  = openai.ChatCompletion.create(
#      11         model="gpt-3.5-turbo",
#      12         messages=[
#      13             {
#      14                 "role": "system",
#      15                 "content": "You will be provided with statements, and your task is to convert them to standard English.",
#      16             },
#      17             {
#      18                 "role": "user",
#      19                 "content": text,
# ...

# %%
# text story genrated
import openai  
systemContent="Imagine you are a skilled storyteller tasked with creating a compelling narrative based on the following plot outline. Your goal is to generate a detailed and realistic story that captivates the reader."
userContent="""In the past, there was a cruel ruler whose name was Pharaoh. He believed he was a god, but God sent a prophet whose name was Musa. Musa told Pharaoh that he was not god, but Pharaoh insisted that he was. Musa explained that God had sent him as a prophet and asked for a miracle (mujiza).

Pharaoh accused Musa of being a magician, and a competition ensued between Musa and Pharaoh at that time. Musa made the magicians throw down their staffs, and they turned into snakes. Musa's staff turned into a huge snake and devoured the magicians' snakes. Witnessing this, the magicians acknowledged Musa as the true prophet of Allah. However, Pharaoh still did not believe Musa and continued to claim he was a god. Ultimately, Pharaoh punished the magicians for believing in Musa and refused to accept him as a prophet. 
"""
def chat(userContents: str)  :
    response  = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
         messages=[
            {"role": "system",
             "content": systemContent
             },
            {"role": "user",
             "content": userContents
             }
        ],
        
    )
    return response.choices[0].message.content


print(chat(userContent))
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[3], line 24
#       9     response  = openai.ChatCompletion.create(
#      10         model="gpt-3.5-turbo",
#      11          messages=[
#    (...)
#      19
#      20     )
#      21     return response.choices[0].message.content
# ---> 24 print(chat(userContent))
#
# Cell In[3], line 9, in chat(userContents)
#       8 def chat(userContents: str)  :
# ----> 9     response  = openai.ChatCompletion.create(
#      10         model="gpt-3.5-turbo",
#      11          messages=[
#      12             {"role": "system",
#      13              "content": systemContent
#      14              },
#      15             {"role": "user",
#      16              "content": userContents
#      17              }
#      18         ],
#      19
#      20     )
#      21     return response.choices[0].message.content
#
# ...

# %%
# ceate a
import openai
from openai import OpenAI

os.environ["OPENAI_API_KEY"]=''
# Initialize OpenAI client
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
 

def generate_scenes(story):
    # Define the prompt to split the story into scenes
    prompt = f"Split the following story into scenes:\n\n{story}\n\nProvide each scene with a title and a brief summary."

    # Make the API request
    response = client.chat.completions.create(
       api_key = '',
       model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ]
    )

    # Extract the response
    scenes = response.choices[0].message.content
    return scenes

# Example usage
story = """
Ali, a poor student, struggles to continue his education but finds support and encouragement from his teacher, Mr. Hassan. 
Despite numerous obstacles, Ali works hard on his assignments and eventually succeeds, gaining recognition and respect.
"""

scenes = generate_scenes(story)
print(scenes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 33
#      27 # Example usage
#      28 story = """
#      29 Ali, a poor student, struggles to continue his education but finds support and encouragement from his teacher, Mr. Hassan.
#      30 Despite numerous obstacles, Ali works hard on his assignments and eventually succeeds, gaining recognition and respect.
#      31 """
# ---> 33 scenes = generate_scenes(story)
#      34 print(scenes)
#
# Cell In[7], line 14, in generate_scenes(story)
#      11 prompt = f"Split the following story into scenes:\n\n{story}\n\nProvide each scene with a title and a brief summary."
#      13 # Make the API request
# ---> 14 response = client.chat.completions.create(
# ...

# %%
import openai

# Define the system content
systemContent = "Imagine you are a skilled storyteller tasked with creating a compelling narrative based on the following plot outline. Your goal is to generate a detailed and realistic story that captivates the reader."

# Function to correct text
def chat(text: str):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You will be provided with statements, and your task is to convert them to standard English."},
            {"role": "user", "content": text}
        ],
        max_tokens=500
    )
    return response.choices[0].message['content']

# Function to generate a story
def chat2(userContents: str):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": systemContent},
            {"role": "user", "content": userContents}
        ],
        max_tokens=1500  # Increase max_tokens if the story is long
    )
    return response.choices[0].message['content']

# Function to generate scenes
def generate_scenes(story: str):
    prompt = f"Split the following story into scenes:\n\n{story}\n\nProvide each scene with a title and a brief summary."
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=500
    )
    return response.choices[0].message['content']

# Example usage
userContent = """
A 24 year old boy seeing out from a train’s window shouted…
“Dad, look the trees are going behind!”
Dad smiled and a young couple sitting nearby, looked at the 24 year old’s childish behavior with pity, suddenly he again exclaimed…
“Dad, look the clouds are running with us!”
The couple couldn’t resist and said to the old man…
“Why don’t you take your son to a good doctor?” The old man smiled and said…“I did and we are just coming from the hospital, my son was blind from birth, he just got his eyes today.”
Every single person on the planet has a story. Don’ t judge people be fore you truly know them. The truth might surprise you
"""

# Correct the text
corrected_text = chat(userContent)

# Generate the story based on corrected text
story_generated = chat2(corrected_text)

# Generate scenes from the story
create_scenes = generate_scenes(story_generated)

# Print results
print("Corrected Text:\n", corrected_text)
print("\nGenerated Story:\n", story_generated)
print("\nScenes:\n", create_scenes)

# %% [markdown]
# Corrected Text:
#  A 24-year-old man looking out from a train window excitedly shouted, "Dad, look, the trees are moving behind us!" His father smiled as a young couple nearby observed the man's childlike behavior with pity. Suddenly, he exclaimed again, "Dad, look, the clouds are running alongside us!" The couple, unable to resist, said to the father, "Why don't you take your son to a good doctor?" The father smiled and replied, "I did. We are returning from the hospital where my son, who has been blind since birth, just received his eyes today." This story serves as a reminder that every person has a unique and often surprising story. It cautions against making judgments about others before truly understanding them.
#
# Generated Story:
#  In a bustling train compartment, the rhythmic clacking of the wheels on the tracks filled the air as passengers settled into their seats for the journey ahead. Among them sat a 24-year-old man, his face pressed close to the window, eyes wide with wonder as he gazed out at the passing scenery. The man's father, seated beside him, observed his son's excitement with a warm smile, savoring the moment.
#
# "Look, Dad, the trees are moving behind us!" the young man exclaimed, his voice tinged with childlike delight. His father chuckled softly, a mix of fondness and pride in his eyes. Nearby, a young couple exchanged a glance, their expressions clouded with pity as they watched the scene unfold.
#
# Before long, the young man's voice rang out once more, filled with uncontainable joy, "Dad, look, the clouds are running alongside us!" The couple, unable to resist their curiosity, leaned in to speak to the father discreetly, "Why don't you take your son to a good doctor? It seems he might need some help."
#
# The father turned to face the couple, his eyes reflecting a mix of understanding and patience. "I did," he replied softly, a hint of pride in his voice. "We are returning from the hospital where my son, who has been blind since birth, just received his eyes today."
#
# The young couple's eyes widened in shock, their faces flushing with embarrassment at their hasty assumptions. Suddenly, the train compartment seemed to be filled with a weighty silence, the realization of their misjudgment hanging heavy in the air.
#
# As the train continued its journey, the young man continued to gaze out of the window, his newfound eyes drinking in the world around him with awe and wonder. The father sat beside him, a silent witness to the miracle that had unfolded before them, a testament to the resilience of the human spirit and the power of hope.
#
# The story of the young man on the train serves as a poignant reminder that each person carries within them a unique and often hidden story, one that defies assumptions and challenges preconceived notions. It urges us to approach others with empathy and understanding, to look beyond the surface and seek to uncover the beauty and complexity that lies within.
#
# Scenes:
#  Scene 1: The Journey Begins
# Summary: The young man and his father embark on a train journey, with the young man experiencing the world through his newfound eyes.
#
# Scene 2: Misjudgment
# Summary: The young couple misunderstand the situation and make assumptions about the young man's behavior, prompting a revelation from the father.
#
# Scene 3: The Miracle Unfolds
# Summary: The truth about the young man's recent eye surgery is revealed, leading to a profound realization for all present in the train compartment.
#
# Scene 4: A Lesson in Empathy
# Summary: The passengers learn a valuable lesson about empathy and the importance of looking beyond appearances and assumptions.

# %%
import openai

# Define the system content
systemContent = "Imagine you are a skilled storyteller tasked with creating a compelling narrative based on the following plot outline. Your goal is to generate a detailed and realistic story that captivates the reader."

# Function to correct text
def chat(text: str):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You will be provided with statements, and your task is to convert them to standard English."},
            {"role": "user", "content": text}
        ],
        max_tokens=500
    )
    return response.choices[0].message['content']

# Function to generate a story
def chat2(userContents: str):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": systemContent},
            {"role": "user", "content": userContents}
        ],
        max_tokens=1500  # Increase max_tokens if the story is long
    )
    return response.choices[0].message['content']

# Function to generate scenes
def generate_scenes(story: str):
    prompt = (
        f"Split the following story into scenes. Each scene should include a brief summary and the detailed text. "
        f"Format each scene as follows:\n\n"
        f"{{\n    \"summary\": \"Brief summary of the scene.\",\n    \"actual_text\": \"Detailed text of the scene.\"\n}}"
        f"\n\nStory:\n{story}"
    )
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        
    )
    return response.choices[0].message['content']

# Example usage
userContent = """
A 24 year old boy seeing out from a train’s window shouted…
“Dad, look the trees are going behind!”
Dad smiled and a young couple sitting nearby, looked at the 24 year old’s childish behavior with pity, suddenly he again exclaimed…
“Dad, look the clouds are running with us!”
The couple couldn’t resist and said to the old man…
“Why don’t you take your son to a good doctor?” The old man smiled and said…“I did and we are just coming from the hospital, my son was blind from birth, he just got his eyes today.”
Every single person on the planet has a story. Don’ t judge people be fore you truly know them. The truth might surprise you
"""

# Correct the text
corrected_text = chat(userContent)

# Generate the story based on corrected text
story_generated = chat2(corrected_text)

# Generate scenes from the story
create_scenes = generate_scenes(story_generated)

# Print results
print("Corrected Text:\n", corrected_text)
print("\nGenerated Story:\n", story_generated)
print("\nScenes:\n", create_scenes)

# %% [markdown]
# orrected Text:
#  A 24-year-old young man looking out from a train window said, "Dad, look, the trees are moving behind us!" His father smiled, and a young couple nearby observed the young man's innocent behavior with pity. Suddenly, he exclaimed again, "Dad, look, the clouds are moving along with us!" The couple couldn't help themselves and remarked to the older man, "Why don't you take your son to a good doctor?" The old man smiled and replied, "I did, and we are just returning from the hospital. My son was blind from birth, and he just regained his eyesight today." This story serves as a reminder that every individual has a unique story, and we should avoid judging others before truly understanding them, as the truth may surprise us.
#
# Generated Story:
#  In a bustling train compartment rattling along a scenic countryside route, a 24-year-old young man sat by the window, his face pressed against the glass as he gazed outside with wide eyes. "Dad, look, the trees are moving behind us!" he exclaimed with childlike wonder, his voice filled with excitement and innocence.
#
# His father, a kind and gentle man with silver hair and a warm smile, turned to his son with a soft chuckle. "That's right, son," he replied, admiration shining in his eyes for the son he deeply loved.
#
# Nearby, a young couple observed the interaction with a mix of curiosity and pity in their eyes. They exchanged a concerned glance, their hearts heavy at the sight of the young man's apparent confusion and naivety.
#
# But just as they were about to whisper their worries to the father, the young man's voice rang out once more, filled with newfound amazement. "Dad, look, the clouds are moving along with us!" he exclaimed, his joy infectious and pure.
#
# Unable to contain their sympathy any longer, the young couple leaned in towards the older man and voiced their concerns in hushed tones. "Why don't you take your son to a good doctor?" they suggested gently, their words laced with compassion.
#
# The father, a man of unwavering patience and endless love, simply smiled in response to the couple's well-intentioned advice. "I did," he replied, his voice tinged with a quiet pride. "And we are just returning from the hospital. My son was blind from birth, and he just regained his eyesight today."
#
# As the weight of his words settled in the air, the young couple's eyes widened in realization, their hearts suddenly filled with a mix of astonishment and humility. They had judged too quickly, assuming they knew the full story without truly understanding the depth of the young man's journey.
#
# In that fleeting moment on the train, surrounded by the rhythmic hum of the engine and the beauty of the passing landscape, a powerful lesson unfolded before them. It was a poignant reminder that every individual carries a unique story within them, a narrative shaped by experiences and circumstances unknown to outsiders.
#
# The young man, now beholding the world with newfound sight and wonder, continued to marvel at the moving scenery outside, his father by his side, guiding him through this remarkable journey of discovery and rediscovery.
#
# And as the train carried them forward, the young couple sat in contemplative silence, their hearts forever changed by the poignant lesson of empathy and understanding they had learned that day. For they had witnessed firsthand the beauty that emerges when we choose compassion over judgment and seek to truly see others for who they are, beyond the surface of appearances.
#
# Scenes:
#  1. {
#     "summary": "A young man on a train marvels at newfound sight while his father watches with pride.",
#     "actual_text": "In a bustling train compartment, a 24-year-old man enthralled by the passing landscape shares his amazement with his father. The young man, blind from birth, experiences the world for the first time after a successful surgery, marveling at simple sights like moving trees and clouds. His father, brimming with love and admiration, watches his son's joy with pride."
# }
#
# 2. {
#     "summary": "A concerned young couple misinterprets the scene and voices their worries to the man.",
#     "actual_text": "Observing the interaction between the young man and his father, a couple nearby misinterprets the situation, assuming the young man's innocence signifies confusion. Filled with pity and concern, they approach the father and suggest seeking medical help for his son, unaware of the true circumstances behind the young man's wonder."
# }
#
# 3. {
#     "summary": "The father reveals the true story, showcasing his son's journey from blindness to sight.",
#     "actual_text": "In response to the couple's well-intentioned advice, the father gently reveals his son's extraordinary journey. He explains that his son was blind from birth and had just regained his eyesight that day after a successful surgery. The revelation shifts the perspective of the young couple, prompting a realization of their quick judgment and lack of understanding."
# }
#
# 4. {
#     "summary": "A profound lesson in empathy is learned by the young couple as they gain a new perspective.",
#     "actual_text": "The moment of truth resonates deeply with the young couple as they grasp the profound lesson of empathy and humility. Witnessing the father and son's bond, they are humbled by their own assumptions and the importance of looking beyond surface appearances. Through this encounter, they learn the transformative power of compassion and genuine understanding."
# }]

# %% [markdown]
#
#
# Generated Story:
#  In a bustling train compartment rattling along a scenic countryside route, a 24-year-old young man sat by the window, his face pressed against the glass as he gazed outside with wide eyes. "Dad, look, the trees are moving behind us!" he exclaimed with childlike wonder, his voice filled with excitement and innocence.
#
# His father, a kind and gentle man with silver hair and a warm smile, turned to his son with a soft chuckle. "That's right, son," he replied, admiration shining in his eyes for the son he deeply loved.
#
# Nearby, a young couple observed the interaction with a mix of curiosity and pity in their eyes. They exchanged a concerned glance, their hearts heavy at the sight of the young man's apparent confusion and naivety.
#
# But just as they were about to whisper their worries to the father, the young man's voice rang out once more, filled with newfound amazement. "Dad, look, the clouds are moving along with us!" he exclaimed, his joy infectious and pure.
#
# Unable to contain their sympathy any longer, the young couple leaned in towards the older man and voiced their concerns in hushed tones. "Why don't you take your son to a good doctor?" they suggested gently, their words laced with compassion.
#
# The father, a man of unwavering patience and endless love, simply smiled in response to the couple's well-intentioned advice. "I did," he replied, his voice tinged with a quiet pride. "And we are just returning from the hospital. My son was blind from birth, and he just regained his eyesight today."
#
# As the weight of his words settled in the air, the young couple's eyes widened in realization, their hearts suddenly filled with a mix of astonishment and humility. They had judged too quickly, assuming they knew the full story without truly understanding the depth of the young man's journey.
#
# In that fleeting moment on the train, surrounded by the rhythmic hum of the engine and the beauty of the passing landscape, a powerful lesson unfolded before them. It was a poignant reminder that every individual carries a unique story within them, a narrative shaped by experiences and circumstances unknown to outsiders.
#
# The young man, now beholding the world with newfound sight and wonder, continued to marvel at the moving scenery outside, his father by his side, guiding him through this remarkable journey of discovery and rediscovery.
#
# And as the train carried them forward, the young couple sat in contemplative silence, their hearts forever changed by the poignant lesson of empathy and understanding they had learned that day. For they had witnessed firsthand the beauty that emerges when we choose compassion over judgment and seek to truly see others for who they are, beyond the surface of appearances.
#
# Scenes:
#  1. {
#     "summary": "A young man on a train marvels at newfound sight while his father watches with pride.",
#     "actual_text": "In a bustling train compartment, a 24-year-old man enthralled by the passing landscape shares his amazement with his father. The young man, blind from birth, experiences the world for the first time after a successful surgery, marveling at simple sights like moving trees and clouds. His father, brimming with love and admiration, watches his son's joy with pride."
# }
#
# 2. {
#     "summary": "A concerned young couple misinterprets the scene and voices their worries to the man.",
#     "actual_text": "Observing the interaction between the young man and his father, a couple nearby misinterprets the situation, assuming the young man's innocence signifies confusion. Filled with pity and concern, they approach the father and suggest seeking medical help for his son, unaware of the true circumstances behind the young man's wonder."
# }
#
# 3. {
#     "summary": "The father reveals the true story, showcasing his son's journey from blindness to sight.",
#     "actual_text": "In response to the couple's well-intentioned advice, the father gently reveals his son's extraordinary journey. He explains that his son was blind from birth and had just regained his eyesight that day after a successful surgery. The revelation shifts the perspective of the young couple, prompting a realization of their quick judgment and lack of understanding."
# }
#
# 4. {
#     "summary": "A profound lesson in empathy is learned by the young couple as they gain a new perspective.",
#     "actual_text": "The moment of truth resonates deeply with the young couple as they grasp the profound lesson of empathy and humility. Witnessing the father and son's bond, they are humbled by their own assumptions and the importance of looking beyond surface appearances. Through this encounter, they learn the transformative power of compassion and genuine understanding."
# }]

# %%
import os
import openai
print( os.getenv('OPENAI_API_KEY'))
test = ""

openai.api_key=test
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]
response = get_completion('hi')
print(response)
# Out:
# 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
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[4], line 15
#       9     response = openai.ChatCompletion.create(
#      10         model=model,
#      11         messages=messages,
#      12         temperature=0, # this is the degree of randomness of the model's output
#      13     )
#      14     return response.choices[0].message["content"]
# ---> 15 response = get_completion('hi')
#      16 print(response)
#
# Cell In[4], line 9, in get_completion(prompt, model)
#       7 def get_completion(prompt, model="gpt-3.5-turbo"):
#       8     messages = [{"role": "user", "content": prompt}]
# ----> 9     response = openai.ChatCompletion.create(
#      10         model=model,
#      11         messages=messages,
# ...
